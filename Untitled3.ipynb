# %% [markdown]
# <a href="https://colab.research.google.com/github/abdhsn8/Saad/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import Image, ImageOps
import sys
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
import pickle as pik

# %%
img_original = Image.open('/content/download.jpg')

#show image
display(img_original)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=349x144 at 0x7FEA409B3750>

# %%
img_gray = Image.open('/content/download.jpg').convert('L')

#show image
display(img_gray)

img.save('/content/Capture_gray.JPG')
# Out:
# <PIL.Image.Image image mode=L size=349x144 at 0x7FEA40AC7850>

# %%
img_invert = Image.open('/content/download.jpg')
im_invert = ImageOps.invert(img_invert)

#show image
display(im_invert)

im_invert.save('/content/Capture_con.JPG', quality=95)
# Out:
# <PIL.Image.Image image mode=RGB size=349x144 at 0x7FEA3F9644D0>

# %%
r, g, b = img_original.split()
display(r)
display(g)
display(b)
# Out:
# <PIL.Image.Image image mode=L size=349x144 at 0x7FEA3F964950>
# <PIL.Image.Image image mode=L size=349x144 at 0x7FEA3F964C90>
# <PIL.Image.Image image mode=L size=349x144 at 0x7FEA3F964E50>

# %%
Bl,W = img_gray.split()
display(Bl)
display(W)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-9b5bd1f3477b> in <module>()
# ----> 1 Bl,W = img_gray.split()
#       2 display(Bl)
#       3 display(W)
#
# ValueError: not enough values to unpack (expected 2, got 1)
